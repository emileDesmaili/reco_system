# %%
import pandas as pd
from streamlit_assets.components import get_recos_users

# %% [markdown]
# ### Exploring movielens data for recos

# %%
criterion = pd.read_csv('data/criterion.csv')
movies = pd.read_csv('data/movielens/movies_metadata.csv')
# Out:
# C:\Users\EmileESMAILI\AppData\Local\Temp\ipykernel_14752\1242716275.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('data/movielens/movies_metadata.csv')

# %%
criterion.head()
# Out:
#    Unnamed: 0                           Title  \
# 0           0  2 or 3 Things I Know About Her
# 1           1                    3:10 to Yuma
# 2           2                         3 Women
# 3           3    4 Months, 3 Weeks and 2 Days
# 4           4                              8½
#
#                                          Description          Director  \
# 0  In2 or 3 Things I Know About Her(2 ou 3 choses...   Jean-Luc Godard
# 1  In this beautifully shot, psychologically comp...      Delmer Daves
# 2  In a dusty, underpopulated California resort t...     Robert Altman
# 3  Romanian filmmaker Cristian Mungiu shot to int...   Cristian Mungiu
# 4  Marcello Mastroianni plays Guido Anselmi, a di...  Federico Fellini
#
#                                              Country    Year  \
# 0                                             France  1967.0
# 1                                      United States  1957.0
# 2                                      United States  1977.0
# 3                                            Romania  2007.0
# 4  Italy,                                        ...  1963.0
#
#                                             Language  \
# 0                                             French
# 1                                            English
# 2                                            English
# 3                                           Romanian
# 4  German,                                       ...
#
#                                                Image
# 0  https://s3.amazonaws.com/criterion-production/...
# 1  https://s3.amazonaws.com/criterion-production/...
# 2  https://s3.amazonaws.com/criterion-production/...
# 3  https://s3.amazonaws.com/criterion-production/...
# 4  https://s3.amazonaws.com/criterion-production/...

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
merged = movies.merge(criterion, left_on='title', right_on='Title')

# %%
merged.head()
# Out:
#    adult belongs_to_collection budget  \
# 0  False                   NaN      0
# 1  False                   NaN      0
# 2  False                   NaN      0
# 3  False                   NaN      0
# 4  False                   NaN      0
#
#                                               genres homepage      id  \
# 0                      [{'id': 18, 'name': 'Drama'}]      NaN   16420
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   47697
# 2                      [{'id': 18, 'name': 'Drama'}]      NaN   44006
# 3                                                 []      NaN  119928
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...      NaN   31174
#
#      imdb_id original_language original_title  \
# 0  tt0114057                en        Othello
# 1  tt0045251                en        Othello
# 2  tt0059555                en        Othello
# 3  tt0082861                en        Othello
# 4  tt0114279                en    Richard III
#
#                                             overview  ... vote_average  \
# 0  The evil Iago pretends to be friend of Othello...  ...          7.0
# 1  Desdemona, daughter of a Venetian aristocrat, ...  ...          6.5
# 2          The 1965 version of the Shakespeare play.  ...          6.1
# 3  Iago and a comrade-in-arms are outside the Ven...  ...          9.5
# 4  Shakespeare's Play transplanted into a 1930s s...  ...          6.9
#
#   vote_count Unnamed: 0        Title  \
# 0       33.0        812      Othello
# 1       35.0        812      Othello
# 2        9.0        812      Othello
# 3        2.0        812      Othello
# 4       50.0        905  Richard III
#
#                                          Description          Director  \
# 0  Gloriously cinematic despite its tiny budget, ...      Orson Welles
# 1  Gloriously cinematic despite its tiny budget, ...      Orson Welles
# 2  Gloriously cinematic despite its tiny budget, ...      Orson Welles
# 3  Gloriously cinematic despite its tiny budget, ...      Orson Welles
# 4  InRichard III,director, producer, and star Lau...  Laurence Olivier
#
#           Country    Year Language  \
# 0   United States  1952.0  English
# 1   United States  1952.0  English
# 2   United States  1952.0  English
# 3   United States  1952.0  English
# 4  United Kingdom  1955.0  English
#
#                                                Image
# 0  https://s3.amazonaws.com/criterion-production/...
# 1  https://s3.amazonaws.com/criterion-production/...
# 2  https://s3.amazonaws.com/criterion-production/...
# 3  https://s3.amazonaws.com/criterion-production/...
# 4  https://s3.amazonaws.com/criterion-production/...
#
# [5 rows x 32 columns]
